# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# ML libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve

# %%
# SMOTE
from imblearn.over_sampling import SMOTE

# %%
import sys
# !{sys.executable} -m pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.14.2-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in C:\Users\Shreyash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn) (2.4.1)
# Requirement already satisfied: scipy<2,>=1.11.4 in C:\Users\Shreyash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn) (1.17.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in C:\Users\Shreyash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn) (1.8.0)
# Collecting sklearn-compat<0.2,>=0.1.6 (from imbalanced-learn)
#   Downloading sklearn_compat-0.1.6-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: joblib<2,>=1.2.0 in C:\Users\Shreyash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in C:\Users\Shreyash\AppData\Local\Programs\Python\Python314\Lib\site-packages (from imbalanced-learn) (3.6.0)
# Downloading imbalanced_learn-0.14.2-py3-none-any.whl (236 kB)
# Downloading sklearn_compat-0.1.6-py3-none-any.whl (22 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn
#
#    ---------------------------------------- 0/2 [sklearn-compat]
#    ---------------------------------------- 0/2 [sklearn-compat]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    ---------------------------------------- 2/2 [imbalanced-learn]
#
# Successfully installed imbalanced-learn-0.14.2 sklearn-compat-0.1.6

# %%
df = pd.read_csv("credit_risk_dataset.csv")
df.head
# Out:
# <bound method NDFrame.head of        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0             PERSONAL          D      35000          16.02            1
# 1            EDUCATION          B       1000          11.14            0
# 2              MEDICAL          C       5500          12.87            1
# 3              MEDICAL          C      35000          15.23            1
# 4              MEDICAL          C      35000          14.27            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.59                         Y
# 1                     0.10                         N
# 2                     0.57                         N
# 3                     0.53                         N
# 4                     0.55                         Y
# ...                    ...                       ...
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 32576                          30
# 32577                          19
# 32578                          28
# 32579                          26
# 32580                          30
#
# [32581 rows x 12 columns]>

# %%
target_col = "loan_status"

# %%
df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
df = df.fillna(df.mean(numeric_only = True))

# %%
df = pd.get_dummies(df, drop_first= True)

# %%
import numpy as np

num_cols = df.select_dtypes(include=np.number).columns
z_scores = (df[num_cols] - df[num_cols].mean()) / df[num_cols].std()
df_clean = df[(np.abs(z_scores) < 3).all(axis=1)]

print("Before: ",df.shape)
print("After: ",df_clean.shape)
# Out:
# Before:  (32581, 23)
# After:  (30881, 23)

# %%
X = df_clean.drop(target_col, axis = 1)
y = df_clean[target_col]

# %%
from imblearn.over_sampling import SMOTE

print("Before SMOTE: ")
print(y.value_counts())

smote = SMOTE(random_state = 42)
X_resampled, y_resampled = smote.fit_resample(X, y)

print("After SMOTE: ")
print(pd.Series(y_resampled).value_counts())
# Out:
# Before SMOTE:
# loan_status
# 0    24365
# 1     6516
# Name: count, dtype: int64
# After SMOTE:
# loan_status
# 0    24365
# 1    24365
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled,
    test_size = 0.2,
    random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(
    penalty = "elasticnet",
    solver = "saga",
    l1_ratio = 0.5,
    max_iter = 5000
)

model.fit(X_train, y_train)
# Out:
# C:\Users\Shreyash\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# C:\Users\Shreyash\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(l1_ratio=0.5, max_iter=5000, penalty='elasticnet',
#                    solver='saga')

# %%
from sklearn.metrics import roc_auc_score

y_probs = model.predict_proba(X_test)[:,1]

auc = roc_auc_score(y_test, y_probs)
print("ROC-AUC Score: ", auc)
# Out:
# ROC-AUC Score:  0.7422449141080285

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

fpr, tpr, _= roc_curve(y_test, y_probs)

plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {auc:.3f}")

plt.Xlable("False Positive Rate")
plt.ylable("True Positive Rate")
plt.title("ROC curve")
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 9
#       6 plt.figure()
#       7 plt.plot(fpr, tpr, label=f"AUC = {auc:.3f}")
# ----> 9 plt.Xlable("False Positive Rate")
#      10 plt.ylable("True Positive Rate")
#      11 plt.title("ROC curve")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'Xlable'

# %%
df["loan_status"].value_counts()
# Out:
# loan_status
# 0    25473
# 1     7108
# Name: count, dtype: int64
